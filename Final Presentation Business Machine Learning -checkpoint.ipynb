# %%
#https://www.machinecurve.com/index.php/2020/02/09/how-to-build-a-convnet-for-cifar-10-and-cifar-100-classification-with-keras/

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import numpy as np
from keras.models import Sequential
from keras.layers import MaxPooling2D, Conv2D, Flatten, Dense, Activation, Dropout
from keras.datasets import cifar100

from tensorflow.keras.utils import to_categorical

# %%
print('cifar100 fine')
(X_train, y_train), (X_test, y_test) = cifar100.load_data()
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# cifar100 fine
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)
# (50000, 1)
# (10000, 1)

# %%
cifar100
# Out:
# <module 'keras.datasets.cifar100' from 'C:\\Users\\akint\\anaconda3\\lib\\site-packages\\keras\\datasets\\cifar100.py'>

# %%
# Show randomly 16 images in the CIFAR-100
plt.figure(figsize=(10, 10))
for i in range (16):
  rand_num = np.random.randint(0, 50000)
  cifar_img = plt.subplot(4,4, i+1)
  plt.imshow(X_train[rand_num])

# %%
# Normalize images
train_images = X_train.astype('float32')/255
test_images = X_test.astype('float32')/255

# Transform labels
train_labels = to_categorical(y_train)
test_labels = to_categorical(y_test)

# %%
# Plot function for visualisation training process
import matplotlib.pyplot as plt

def training_plot(history):
  acc = history.history['acc']
  val_acc = history.history['val_acc']
  loss = history.history['loss']
  val_loss = history.history['val_loss']
  epochs = range(1, len(acc) + 1)
  plt.plot(epochs, acc, 'bo', label='Training acc')
  plt.plot(epochs, val_acc, 'b', label='Validation acc')
  plt.title('Training and validation accuracy')
  plt.legend()
  plt.figure()
  plt.plot(epochs, loss, 'bo', label='Training loss')
  plt.plot(epochs, val_loss, 'b', label='Validation loss')
  plt.title('Training and validation loss')
  plt.legend()
  plt.show()

# %%
#Adding Layers and creating parameters 
from keras.models import Sequential
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPool2D
from keras.layers.core import Dense,Activation,Dropout,Flatten

from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.initializers import RandomNormal, Constant
model = Sequential()
 
model.add(Conv2D(256,(3,3),padding='same',input_shape=(32,32,3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(256,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.2))
 
model.add(Conv2D(512,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(512,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.2))

model.add(Conv2D(512,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(512,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.2))

model.add(Conv2D(512,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(512,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(1024))
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization(momentum=0.95, 
        epsilon=0.005,
        beta_initializer=RandomNormal(mean=0.0, stddev=0.05), 
        gamma_initializer=Constant(value=0.9)))
model.add(Dense(100,activation='softmax'))
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_25 (Conv2D)           (None, 32, 32, 256)       7168
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_18 (Activation)   (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 32, 32, 256)       590080
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_19 (Activation)   (None, 32, 32, 256)       0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 16, 16, 256)       0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 16, 16, 512)       1180160
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_20 (Activation)   (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 16, 16, 512)       2359808
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_21 (Activation)   (None, 16, 16, 512)       0
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 8, 8, 512)         0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 8, 8, 512)         0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 8, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_22 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 8, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_23 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 4, 4, 512)         0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 4, 4, 512)         2359808
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 4, 4, 512)         2048
# _________________________________________________________________
# activation_24 (Activation)   (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 4, 4, 512)         2359808
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 4, 4, 512)         2048
# _________________________________________________________________
# activation_25 (Activation)   (None, 4, 4, 512)         0
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# activation_26 (Activation)   (None, 1024)              0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 1024)              4096
# _________________________________________________________________
# dense_9 (Dense)              (None, 100)               102500
# =================================================================
# Total params: 15,795,556
# Trainable params: 15,786,340
# Non-trainable params: 9,216
# _________________________________________________________________

# %%
# Adding data augmentation for creating more images
# Divide train and validation set 
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Configuration for creating new images
train_datagen = ImageDataGenerator(
    rotation_range=20,
    horizontal_flip=True,
)

X_train, X_validation, y_train, y_validation = train_test_split(train_images, train_labels, test_size=0.2, random_state=93)
train_datagen.fit(X_train)

# %%
# Configure the model for training
from tensorflow.keras import optimizers
model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.RMSprop(learning_rate=1e-4),
              metrics=['acc'])

# %%
# Training model
#Ran 100 Epoch with 100 steps in each to get as accurate an answer as possible.
#Ran for approximately 24 hours 
import time
training_start = time.time()
history = model.fit(train_datagen.flow(X_train, y_train, batch_size=64),
          steps_per_epoch=100, 
          epochs=100,
          validation_data=(X_validation, y_validation),
          verbose=1)
training_stop = time.time()
training_time = training_stop - training_start
print(f"Training time: {training_time}")
# Out:
# Epoch 1/100
# 100/100 [==============================] - 1259s 13s/step - loss: 4.1659 - acc: 0.0778 - val_loss: 5.2411 - val_acc: 0.0120
# Epoch 2/100
# 100/100 [==============================] - 984s 10s/step - loss: 4.0023 - acc: 0.0986 - val_loss: 5.0686 - val_acc: 0.0193
# Epoch 3/100
# 100/100 [==============================] - 1034s 10s/step - loss: 3.8531 - acc: 0.1116 - val_loss: 4.8700 - val_acc: 0.0343
# Epoch 4/100
# 100/100 [==============================] - 942s 9s/step - loss: 3.6928 - acc: 0.1428 - val_loss: 4.4442 - val_acc: 0.0670
# Epoch 5/100
# 100/100 [==============================] - 919s 9s/step - loss: 3.6190 - acc: 0.1481 - val_loss: 3.7354 - val_acc: 0.1388
# Epoch 6/100
# 100/100 [==============================] - 908s 9s/step - loss: 3.5232 - acc: 0.1725 - val_loss: 3.5380 - val_acc: 0.1651
# Epoch 7/100
# 100/100 [==============================] - 881s 9s/step - loss: 3.4133 - acc: 0.1827 - val_loss: 3.3225 - val_acc: 0.2022
# Epoch 8/100
# 100/100 [==============================] - 857s 9s/step - loss: 3.3460 - acc: 0.1966 - val_loss: 3.5104 - val_acc: 0.1754
# Epoch 9/100
# 100/100 [==============================] - 856s 9s/step - loss: 3.2472 - acc: 0.2131 - val_loss: 3.2299 - val_acc: 0.2190
# Epoch 10/100
# 100/100 [==============================] - 876s 9s/step - loss: 3.1554 - acc: 0.2264 - val_loss: 3.0354 - val_acc: 0.2537
# Epoch 11/100
# 100/100 [==============================] - 863s 9s/step - loss: 3.1067 - acc: 0.2395 - val_loss: 3.0972 - val_acc: 0.2393
# Epoch 12/100
# 100/100 [==============================] - 863s 9s/step - loss: 3.0025 - acc: 0.2577 - val_loss: 3.1267 - val_acc: 0.2400
# Epoch 13/100
# 100/100 [==============================] - 880s 9s/step - loss: 2.8988 - acc: 0.2772 - val_loss: 3.0922 - val_acc: 0.2579
# Epoch 14/100
# 100/100 [==============================] - 887s 9s/step - loss: 2.8754 - acc: 0.2745 - val_loss: 2.7427 - val_acc: 0.3090
# Epoch 15/100
# 100/100 [==============================] - 914s 9s/step - loss: 2.8175 - acc: 0.2927 - val_loss: 2.8523 - val_acc: 0.2932
# Epoch 16/100
# 100/100 [==============================] - 906s 9s/step - loss: 2.7264 - acc: 0.3155 - val_loss: 2.6898 - val_acc: 0.3253
# Epoch 17/100
# 100/100 [==============================] - 867s 9s/step - loss: 2.7114 - acc: 0.3181 - val_loss: 2.7702 - val_acc: 0.3069
# Epoch 18/100
# 100/100 [==============================] - 949s 9s/step - loss: 2.6137 - acc: 0.3327 - val_loss: 2.6656 - val_acc: 0.3171
# Epoch 19/100
# 100/100 [==============================] - 892s 9s/step - loss: 2.5799 - acc: 0.3336 - val_loss: 2.8076 - val_acc: 0.2985
# Epoch 20/100
# 100/100 [==============================] - 886s 9s/step - loss: 2.5418 - acc: 0.3472 - val_loss: 2.5680 - val_acc: 0.3417
# Epoch 21/100
# 100/100 [==============================] - 1023s 10s/step - loss: 2.4588 - acc: 0.3553 - val_loss: 2.8849 - val_acc: 0.2952
# Epoch 22/100
# 100/100 [==============================] - 1010s 10s/step - loss: 2.4026 - acc: 0.3800 - val_loss: 2.6095 - val_acc: 0.3407
# Epoch 23/100
# 100/100 [==============================] - 1004s 10s/step - loss: 2.3803 - acc: 0.3797 - val_loss: 2.5044 - val_acc: 0.3715
# Epoch 24/100
# 100/100 [==============================] - 1004s 10s/step - loss: 2.3300 - acc: 0.3853 - val_loss: 2.7783 - val_acc: 0.3277
# Epoch 25/100
# 100/100 [==============================] - 820s 8s/step - loss: 2.2901 - acc: 0.4078 - val_loss: 2.2833 - val_acc: 0.4098
# Epoch 26/100
# 100/100 [==============================] - 819s 8s/step - loss: 2.3035 - acc: 0.3983 - val_loss: 2.4186 - val_acc: 0.3765
# Epoch 27/100
# 100/100 [==============================] - 817s 8s/step - loss: 2.2616 - acc: 0.4044 - val_loss: 2.2844 - val_acc: 0.4087
# Epoch 28/100
# 100/100 [==============================] - 814s 8s/step - loss: 2.1851 - acc: 0.4238 - val_loss: 2.1658 - val_acc: 0.4296
# Epoch 29/100
# 100/100 [==============================] - 814s 8s/step - loss: 2.1873 - acc: 0.4233 - val_loss: 2.4415 - val_acc: 0.3813
# Epoch 30/100
# 100/100 [==============================] - 808s 8s/step - loss: 2.1481 - acc: 0.4400 - val_loss: 2.3480 - val_acc: 0.4047
# Epoch 31/100
# 100/100 [==============================] - 827s 8s/step - loss: 2.0764 - acc: 0.4519 - val_loss: 2.1982 - val_acc: 0.4311
# Epoch 32/100
# 100/100 [==============================] - 806s 8s/step - loss: 2.0437 - acc: 0.4531 - val_loss: 2.1581 - val_acc: 0.4274
# Epoch 33/100
# 100/100 [==============================] - 811s 8s/step - loss: 2.0303 - acc: 0.4625 - val_loss: 2.0385 - val_acc: 0.4640
# Epoch 34/100
# 100/100 [==============================] - 808s 8s/step - loss: 2.0141 - acc: 0.4600 - val_loss: 2.2499 - val_acc: 0.4148
# Epoch 35/100
# 100/100 [==============================] - 810s 8s/step - loss: 1.9669 - acc: 0.4745 - val_loss: 2.3007 - val_acc: 0.4084
# Epoch 36/100
# 100/100 [==============================] - 811s 8s/step - loss: 1.9230 - acc: 0.4864 - val_loss: 2.1594 - val_acc: 0.4298
# Epoch 37/100
# 100/100 [==============================] - 811s 8s/step - loss: 1.9144 - acc: 0.4828 - val_loss: 2.1012 - val_acc: 0.4417
# Epoch 38/100
# 100/100 [==============================] - 816s 8s/step - loss: 1.9247 - acc: 0.4844 - val_loss: 2.1554 - val_acc: 0.4487
# Epoch 39/100
# 100/100 [==============================] - 811s 8s/step - loss: 1.8912 - acc: 0.4883 - val_loss: 2.0438 - val_acc: 0.4572
# Epoch 40/100
# 100/100 [==============================] - 812s 8s/step - loss: 1.8695 - acc: 0.5016 - val_loss: 2.1312 - val_acc: 0.4419
# Epoch 41/100
# 100/100 [==============================] - 815s 8s/step - loss: 1.8544 - acc: 0.5016 - val_loss: 2.2953 - val_acc: 0.4138
# Epoch 42/100
# 100/100 [==============================] - 816s 8s/step - loss: 1.8343 - acc: 0.4998 - val_loss: 2.2409 - val_acc: 0.4252
# Epoch 43/100
# 100/100 [==============================] - 810s 8s/step - loss: 1.8188 - acc: 0.5030 - val_loss: 1.9554 - val_acc: 0.4745
# Epoch 44/100
# 100/100 [==============================] - 813s 8s/step - loss: 1.7640 - acc: 0.5227 - val_loss: 2.0664 - val_acc: 0.4530
# Epoch 45/100
# 100/100 [==============================] - 825s 8s/step - loss: 1.7795 - acc: 0.5177 - val_loss: 2.0417 - val_acc: 0.4666
# Epoch 46/100
# 100/100 [==============================] - 821s 8s/step - loss: 1.7623 - acc: 0.5231 - val_loss: 1.9758 - val_acc: 0.4791
# Epoch 47/100
# 100/100 [==============================] - 829s 8s/step - loss: 1.7580 - acc: 0.5155 - val_loss: 1.9641 - val_acc: 0.4802
# Epoch 48/100
# 100/100 [==============================] - 822s 8s/step - loss: 1.7164 - acc: 0.5327 - val_loss: 2.0473 - val_acc: 0.4663
# Epoch 49/100
# 100/100 [==============================] - 822s 8s/step - loss: 1.7275 - acc: 0.5275 - val_loss: 2.2043 - val_acc: 0.4475
# Epoch 50/100
# 100/100 [==============================] - 825s 8s/step - loss: 1.6862 - acc: 0.5386 - val_loss: 1.9009 - val_acc: 0.4944
# Epoch 51/100
# 100/100 [==============================] - 831s 8s/step - loss: 1.6511 - acc: 0.5445 - val_loss: 1.8462 - val_acc: 0.5001
# Epoch 52/100
# 100/100 [==============================] - 824s 8s/step - loss: 1.6266 - acc: 0.5627 - val_loss: 1.9836 - val_acc: 0.4725
# Epoch 53/100
# 100/100 [==============================] - 838s 8s/step - loss: 1.5986 - acc: 0.5630 - val_loss: 1.9238 - val_acc: 0.4859
# Epoch 54/100
# 100/100 [==============================] - 835s 8s/step - loss: 1.6074 - acc: 0.5597 - val_loss: 1.8824 - val_acc: 0.5001
# Epoch 55/100
# 100/100 [==============================] - 861s 9s/step - loss: 1.5778 - acc: 0.5634 - val_loss: 1.8857 - val_acc: 0.4968
# Epoch 56/100
# 100/100 [==============================] - 840s 8s/step - loss: 1.5952 - acc: 0.5647 - val_loss: 1.9296 - val_acc: 0.4907
# Epoch 57/100
# 100/100 [==============================] - 826s 8s/step - loss: 1.5584 - acc: 0.5695 - val_loss: 1.9823 - val_acc: 0.4807
# Epoch 58/100
# 100/100 [==============================] - 827s 8s/step - loss: 1.5454 - acc: 0.5734 - val_loss: 1.7796 - val_acc: 0.5258
# Epoch 59/100
# 100/100 [==============================] - 834s 8s/step - loss: 1.5448 - acc: 0.5711 - val_loss: 1.8553 - val_acc: 0.5084
# Epoch 60/100
# 100/100 [==============================] - 842s 8s/step - loss: 1.5091 - acc: 0.5808 - val_loss: 1.8808 - val_acc: 0.5024
# Epoch 61/100
# 100/100 [==============================] - 838s 8s/step - loss: 1.4815 - acc: 0.5917 - val_loss: 1.7989 - val_acc: 0.5175
# Epoch 62/100
# 100/100 [==============================] - 843s 8s/step - loss: 1.4895 - acc: 0.5867 - val_loss: 1.7104 - val_acc: 0.5285
# Epoch 63/100
# 100/100 [==============================] - 859s 9s/step - loss: 1.5009 - acc: 0.5856 - val_loss: 1.8061 - val_acc: 0.5158
# Epoch 64/100
# 100/100 [==============================] - 874s 9s/step - loss: 1.4534 - acc: 0.5922 - val_loss: 1.8992 - val_acc: 0.5006
# Epoch 65/100
# 100/100 [==============================] - 874s 9s/step - loss: 1.4466 - acc: 0.5936 - val_loss: 1.9318 - val_acc: 0.5025
# Epoch 66/100
# 100/100 [==============================] - 885s 9s/step - loss: 1.4297 - acc: 0.5978 - val_loss: 1.7820 - val_acc: 0.5214
# Epoch 67/100
# 100/100 [==============================] - 888s 9s/step - loss: 1.4608 - acc: 0.5938 - val_loss: 1.7207 - val_acc: 0.5370
# Epoch 68/100
# 100/100 [==============================] - 862s 9s/step - loss: 1.4006 - acc: 0.6045 - val_loss: 1.7240 - val_acc: 0.5314
# Epoch 69/100
# 100/100 [==============================] - 874s 9s/step - loss: 1.4281 - acc: 0.5959 - val_loss: 1.6815 - val_acc: 0.5476
# Epoch 70/100
# 100/100 [==============================] - 880s 9s/step - loss: 1.3741 - acc: 0.6133 - val_loss: 1.8834 - val_acc: 0.5102
# Epoch 71/100
# 100/100 [==============================] - 869s 9s/step - loss: 1.3705 - acc: 0.6167 - val_loss: 1.8857 - val_acc: 0.5043
# Epoch 72/100
# 100/100 [==============================] - 883s 9s/step - loss: 1.3403 - acc: 0.6217 - val_loss: 1.7656 - val_acc: 0.5315
# Epoch 73/100
# 100/100 [==============================] - 857s 9s/step - loss: 1.3397 - acc: 0.6256 - val_loss: 1.6943 - val_acc: 0.5477
# Epoch 74/100
# 100/100 [==============================] - 869s 9s/step - loss: 1.3212 - acc: 0.6286 - val_loss: 1.6326 - val_acc: 0.5494
# Epoch 75/100
# 100/100 [==============================] - 861s 9s/step - loss: 1.3211 - acc: 0.6275 - val_loss: 1.8001 - val_acc: 0.5245
# Epoch 76/100
# 100/100 [==============================] - 871s 9s/step - loss: 1.2891 - acc: 0.6339 - val_loss: 1.7323 - val_acc: 0.5386
# Epoch 77/100
# 100/100 [==============================] - 852s 9s/step - loss: 1.3009 - acc: 0.6294 - val_loss: 1.7759 - val_acc: 0.5274
# Epoch 78/100
# 100/100 [==============================] - 888s 9s/step - loss: 1.3007 - acc: 0.6397 - val_loss: 1.7213 - val_acc: 0.5402
# Epoch 79/100
# 100/100 [==============================] - 860s 9s/step - loss: 1.2978 - acc: 0.6366 - val_loss: 1.8671 - val_acc: 0.5176
# Epoch 80/100
# 100/100 [==============================] - 848s 8s/step - loss: 1.2732 - acc: 0.6395 - val_loss: 1.7225 - val_acc: 0.5440
# Epoch 81/100
# 100/100 [==============================] - 912s 9s/step - loss: 1.2559 - acc: 0.6480 - val_loss: 1.6454 - val_acc: 0.5556
# Epoch 82/100
# 100/100 [==============================] - 846s 8s/step - loss: 1.2515 - acc: 0.6516 - val_loss: 1.6912 - val_acc: 0.5447
# Epoch 83/100
# 100/100 [==============================] - 827s 8s/step - loss: 1.2196 - acc: 0.6505 - val_loss: 1.5734 - val_acc: 0.5689
# Epoch 84/100
# 100/100 [==============================] - 830s 8s/step - loss: 1.2395 - acc: 0.6419 - val_loss: 1.6855 - val_acc: 0.5474
# Epoch 85/100
# 100/100 [==============================] - 826s 8s/step - loss: 1.2165 - acc: 0.6516 - val_loss: 1.6517 - val_acc: 0.5637
# Epoch 86/100
# 100/100 [==============================] - 834s 8s/step - loss: 1.2105 - acc: 0.6602 - val_loss: 1.5547 - val_acc: 0.5773
# Epoch 87/100
# 100/100 [==============================] - 823s 8s/step - loss: 1.1913 - acc: 0.6572 - val_loss: 1.6117 - val_acc: 0.5694
# Epoch 88/100
# 100/100 [==============================] - 825s 8s/step - loss: 1.1951 - acc: 0.6584 - val_loss: 1.8191 - val_acc: 0.5247
# Epoch 89/100
# 100/100 [==============================] - 818s 8s/step - loss: 1.1858 - acc: 0.6714 - val_loss: 1.5833 - val_acc: 0.5677
# Epoch 90/100
# 100/100 [==============================] - 825s 8s/step - loss: 1.1608 - acc: 0.6597 - val_loss: 1.6408 - val_acc: 0.5614
# Epoch 91/100
# 100/100 [==============================] - 819s 8s/step - loss: 1.1890 - acc: 0.6600 - val_loss: 1.7953 - val_acc: 0.5299
# Epoch 92/100
# 100/100 [==============================] - 821s 8s/step - loss: 1.1430 - acc: 0.6772 - val_loss: 1.7404 - val_acc: 0.5426
# Epoch 93/100
# 100/100 [==============================] - 818s 8s/step - loss: 1.1503 - acc: 0.6741 - val_loss: 1.5833 - val_acc: 0.5733
# Epoch 94/100
# 100/100 [==============================] - 818s 8s/step - loss: 1.1212 - acc: 0.6733 - val_loss: 1.6265 - val_acc: 0.5719
# Epoch 95/100
# 100/100 [==============================] - 826s 8s/step - loss: 1.1149 - acc: 0.6800 - val_loss: 1.6534 - val_acc: 0.5634
# Epoch 96/100
# 100/100 [==============================] - 817s 8s/step - loss: 1.1347 - acc: 0.6744 - val_loss: 1.5882 - val_acc: 0.5771
# Epoch 97/100
# 100/100 [==============================] - 821s 8s/step - loss: 1.0867 - acc: 0.6906 - val_loss: 1.6385 - val_acc: 0.5674
# Epoch 98/100
# 100/100 [==============================] - 816s 8s/step - loss: 1.0955 - acc: 0.6873 - val_loss: 1.6029 - val_acc: 0.5738
# Epoch 99/100
# 100/100 [==============================] - 827s 8s/step - loss: 1.0893 - acc: 0.6856 - val_loss: 1.5944 - val_acc: 0.5697
# Epoch 100/100
# 100/100 [==============================] - 815s 8s/step - loss: 1.0969 - acc: 0.6872 - val_loss: 1.6166 - val_acc: 0.5702
# Training time: 86573.78505206108

# %%
# Visualize training process
training_plot(history)

# %%
#Finding the Overall Accuracy of the Training Dataset 
scores = model.evaluate(test_images, test_labels)
print(f'accuracy on test set: {model.metrics_names[1]} of {scores[1]*100}')
# Out:
# 313/313 [==============================] - 210s 671ms/step - loss: 1.5842 - acc: 0.5756
# accuracy on test set: acc of 57.56000280380249

# %%
# Visualize history
# Plot history: Loss
import matplotlib.pyplot as plt

plt.plot(history.history['val_loss'])
plt.title('Validation loss history')
plt.ylabel('Loss value')
plt.xlabel('No. epoch')
plt.show()

# %%
# Plot history: Accuracy
plt.plot(history.history['val_accuracy'])
plt.title('Validation accuracy history')
plt.ylabel('Accuracy value (%)')
plt.xlabel('No. epoch')
plt.show()

# %%
#Trying to test to see the accuracy of the modelin person
#Issue is that the code will have to be reran in order to make this work and this is not condusive
img, label = test_dataset[550]
plt.imshow(img.permute(1, 2, 0))
print('Label:', dataset.classes[label], ', Predicted:', predict_image(img, model))
