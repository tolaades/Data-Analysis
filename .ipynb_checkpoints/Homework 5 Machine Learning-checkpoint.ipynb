# %%
## import modulas

import tensorflow as tf

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
print('cifar100 fine')
(X_train, y_train), (X_test, y_test) = datasets.cifar100.load_data('fine')
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# cifar100 fine
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)
# (50000, 1)
# (10000, 1)

# %%
## show images size

X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
## plot some example images

plt.figure(figsize=(10,10))
for i in range(20):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.show()

# %%
## build the model

model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(70, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(70, (3, 3), activation='relu'))

# %%
## summary current model

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 13, 13, 70)        20230
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 6, 6, 70)          0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 4, 4, 70)          44170
# =================================================================
# Total params: 65,296
# Trainable params: 65,296
# Non-trainable params: 0
# _________________________________________________________________

# %%
## add more layers

model.add(layers.Flatten())
model.add(layers.Dense(70, activation='relu'))
model.add(layers.Dense(100, activation = 'softmax'))

# %%
## summary the model again

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 13, 13, 70)        20230
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 6, 6, 70)          0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 4, 4, 70)          44170
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1120)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 70)                78470
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                710
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 10)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 70)                770
# _________________________________________________________________
# dense_9 (Dense)              (None, 100)               7100
# =================================================================
# Total params: 152,346
# Trainable params: 152,346
# Non-trainable params: 0
# _________________________________________________________________

# %%
## compile the model

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
## fit the model and save results into 'history'

history =  model.fit(X_train, y_train, epochs=10, 
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 42s 27ms/step - loss: 4.6052 - accuracy: 0.0097 - val_loss: 4.6052 - val_accuracy: 0.0100
# Epoch 2/10
# 1563/1563 [==============================] - 47s 30ms/step - loss: 4.6052 - accuracy: 0.0094 - val_loss: 4.6052 - val_accuracy: 0.0100
# Epoch 3/10
# 1563/1563 [==============================] - 43s 28ms/step - loss: 4.6051 - accuracy: 0.0094 - val_loss: 4.6052 - val_accuracy: 0.0100
# Epoch 4/10
# 1563/1563 [==============================] - 40s 25ms/step - loss: 4.6051 - accuracy: 0.0084 - val_loss: 4.6052 - val_accuracy: 0.0100
# Epoch 5/10
# 1563/1563 [==============================] - 39s 25ms/step - loss: 4.6051 - accuracy: 0.0081 - val_loss: 4.6052 - val_accuracy: 0.0100
# Epoch 6/10
# 1563/1563 [==============================] - 49s 31ms/step - loss: 4.6051 - accuracy: 0.0090 - val_loss: 4.6052 - val_accuracy: 0.0100
# Epoch 7/10
# 1563/1563 [==============================] - 96s 62ms/step - loss: 4.6051 - accuracy: 0.0087 - val_loss: 4.6052 - val_accuracy: 0.0100
# Epoch 8/10
# 1563/1563 [==============================] - 93s 59ms/step - loss: 4.6051 - accuracy: 0.0090 - val_loss: 4.6052 - val_accuracy: 0.0100
# Epoch 9/10
# 1563/1563 [==============================] - 77s 50ms/step - loss: 4.6051 - accuracy: 0.0087 - val_loss: 4.6052 - val_accuracy: 0.0100
# Epoch 10/10
# 1563/1563 [==============================] - 63s 40ms/step - loss: 4.6051 - accuracy: 0.0094 - val_loss: 4.6052 - val_accuracy: 0.0100

# %%
## plot accuracy and val-accuracy vs Epoch

plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

# %%
## show accucary in test data

test_loss, test_acc = model.evaluate(X_test,  y_test)
# Out:
# 313/313 [==============================] - 5s 17ms/step - loss: 4.6052 - accuracy: 0.0100
