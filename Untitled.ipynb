# %%
import numpy as np 
import pandas as pd

# %%
#Bringing in the dataset
df = pd.read_csv('airbnb_nyc_trimmed.csv')

# %%
#Showing Dataset
df
# Out:
#            id                                               name  \
# 0     4951402                         Best Location on the UWS!!
# 1    16103920                       The Executive Loft Manhattan
# 2    35803621   TRANQUIL HAVEN-8 MINS TO JFK/LIRR/AIRTRAIN RM#2.
# 3    12223531                  Spacious and sun-drenched bedroom
# 4    34120534         Sunlit Apartment in the "Friends Building"
# ..        ...                                                ...
# 995  28715332                 TRIBECA/SOHO 2 BEDROOM LUXURY LOFT
# 996  29098862  Quite room. 15 mins to JFK & 20 mins to Manhattan
# 997   3819656                                SoHo/Village Studio
# 998  27529564                                 Queen size bedroom
# 999  31040919                                     Cute apartment
#
#                                            description  host_name  \
# 0    Clean cozy room on the UWS, a minute walk to t...      Sasha
# ...

# %%
#Dropping a column, chose to drop this column becaue the data were all the same. The entirety of the datafrae was from New York, making it redundant to name every single line NewYork. 
df1 = df.drop(columns='market')

# %%
df1.head()
# Out:
#          id                                              name  \
# 0   4951402                        Best Location on the UWS!!
# 1  16103920                      The Executive Loft Manhattan
# 2  35803621  TRANQUIL HAVEN-8 MINS TO JFK/LIRR/AIRTRAIN RM#2.
# 3  12223531                 Spacious and sun-drenched bedroom
# 4  34120534        Sunlit Apartment in the "Friends Building"
#
#                                          description  host_name  \
# 0  Clean cozy room on the UWS, a minute walk to t...      Sasha
# 1  This wonderful apartment is located on a prime...  Francisco
# 2  This spacious bedroom with shared bath is loca...     Sharon
# 3  Spacious and sun-drenched bedroom in Williamsb...       Mimi
# 4  Spacious sun soaked one bedroom apartment in t...     Vaughn
#
#   host_is_superhost  host_total_listings_count host_has_profile_pic  \
# 0                 f                          2                    t
# ...

# %%
df1.info
# Out:
# <bound method DataFrame.info of            id                                               name  \
# 0     4951402                         Best Location on the UWS!!
# 1    16103920                       The Executive Loft Manhattan
# 2    35803621   TRANQUIL HAVEN-8 MINS TO JFK/LIRR/AIRTRAIN RM#2.
# 3    12223531                  Spacious and sun-drenched bedroom
# 4    34120534         Sunlit Apartment in the "Friends Building"
# ..        ...                                                ...
# 995  28715332                 TRIBECA/SOHO 2 BEDROOM LUXURY LOFT
# 996  29098862  Quite room. 15 mins to JFK & 20 mins to Manhattan
# 997   3819656                                SoHo/Village Studio
# 998  27529564                                 Queen size bedroom
# 999  31040919                                     Cute apartment
#
#                                            description  host_name  \
# 0    Clean cozy room on the UWS, a minute walk to t...      Sasha
# ...
